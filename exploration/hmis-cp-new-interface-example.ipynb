# %%
import pandas as pd
import clean

# %%
(hmis, cp) = clean.get_hmis_cp()

# %%
hmis
# Out:
#         Raw Subject Unique Identifier  Participant Site Identifier  \
# 0                               55030                        65600
# 1                               55031                        65601
# 2                               55031                        65601
# 3                               55032                        65602
# 4                               55032                        65602
# 5                               55034                        65604
# 6                               55034                        65604
# 7                               55035                        65605
# 8                               55035                        65605
# 9                               55101                        65671
# 10                              55036                        65606
# 11                              55037                        65607
# 12                              55038                        65608
# ...

# %%
cp
# Out:
#       Caseid  servstart    servend status  Emergency  ReferralAgencyId  \
# 0      13984 2012-09-14 2013-04-26  Close          0                -1
# 1      13984 2012-09-14 2013-04-26  Close          0                -1
# 2      13984 2012-09-14 2013-04-26  Close          0                -1
# 3      13984 2012-09-14 2013-04-26  Close          0                -1
# 4      13984 2012-09-14 2013-04-26  Close          0                -1
# 5      13984 2012-09-14 2013-04-26  Close          0                -1
# 6      13985 2012-09-14 2012-10-15  Close          0               100
# 7      13985 2012-09-14 2012-10-15  Close          0               100
# 8      13986 2012-09-14 2012-10-19  Close          0               841
# 9      13986 2012-09-14 2012-10-19  Close          0               841
# 10     13986 2012-09-14 2012-10-19  Close          0               841
# 11     13987 2012-09-17 2012-10-19  Close        NaN               NaN
# ...
