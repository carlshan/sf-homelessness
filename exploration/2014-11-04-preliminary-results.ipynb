# %%
import pandas as pd
import clean

# %%
program = clean.get_program()

# %% [markdown]
# I think these are the important columns:
#
# - `Subject Unique Identifier` is the personal ID;
# - `Family Identifier` is the family ID we generated using an aggressive connected-componenets method, (this is the one that may change as we hear back from Candace, et al.);
# - The dates should be self explanatory;
# - `Family?` is a boolean variable that's set to `True` iff the family ever checked in as a family with at least one child and at least one adult, per the City's definition of a family.

# %%
columns = ['Subject Unique Identifier','Family Identifier','Program Start Date','Program End Date','Family?']

# %%
program[columns]
# Out:
#         Subject Unique Identifier  Family Identifier Program Start Date  \
# 0                           55030               9972         2013-11-15
# 1                           55031               9973         2013-01-07
# 2                           55031               9973         2013-01-24
# 3                           55032               9973         2013-01-07
# 4                           55032               9973         2013-01-24
# 5                           55034               2368         2012-11-07
# 6                           55034               2368         2013-02-20
# 7                           55035               2368         2013-02-20
# 8                           55035               2368         2012-11-07
# 9                           55101               2368         2013-02-20
# 10                          55036               1594         2013-01-25
# 11                          55037               1594         2013-01-25
# 12                          55038               1594         2013-01-25
# 13                          55045               9975         2013-01-29
# 14                          55047               9975         2013-01-29
# 15                          55046               9975         2013-01-29
# 16                          54902               9943         2012-12-31
# 17                          54902               9943         2013-02-07
# 18                          54902               9943         2013-05-09
# 19                          54902               9943         2013-12-19
# 20                          54903               9943         2012-12-31
# 21                          54903               9943         2013-02-07
# 22                          54903               9943         2013-05-09
# 23                          54903               9943         2013-12-19
# 24                          55055               7061         2013-08-15
# 25                          55055               7061         2013-07-18
# 26                          55055               7061         2013-08-01
# 27                          55055               7061         2013-02-07
# 28                          55055               7061         2013-02-25
# 29                          55055               7061         2013-03-15
# ...                           ...                ...                ...
# 157961                      45334               1254         2013-01-01
# 157962                      45336                NaN         2011-01-12
# 157963                      45336                NaN         2013-01-01
# 157964                      45339                NaN         2011-12-01
# 157965                      45339                NaN         2013-01-01
# 157966                      45340                NaN         2012-04-12
# 157967                      45325                NaN         2013-01-01
# 157968                      45324                NaN         2008-04-30
# 157969                      45345                NaN         2011-07-21
# 157970                      45345                NaN         2013-01-01
# 157971                      45347                NaN         2012-04-16
# 157972                      45347                NaN         2013-01-01
# 157973                      45348                NaN         2009-01-20
# 157974                      45348                NaN         2013-01-01
# 157975                      45350                NaN         2008-03-18
# 157976                      45350                NaN         2013-01-01
# 157977                      45351                NaN         2010-06-02
# 157978                      45351                NaN         2013-01-01
# 157979                      45353               1479         2008-09-12
# 157980                      45353               1479         2013-01-01
# 157981                      45356                NaN         2008-08-04
# 157982                      45356                NaN         2009-02-25
# 157983                      45356                NaN         2013-01-01
# 157984                      45357                NaN         2011-07-18
# 157985                      45357                NaN         2013-01-01
# 157986                      45359               4134         2009-10-20
# 157987                      45359               4134         2012-05-04
# 157988                      45359               4134         2013-01-01
# 157989                      45360                NaN         2009-10-21
# 157990                      45360                NaN         2013-01-01
#
#        Program End Date Family?
# 0            2014-04-24   False
# 1            2013-01-10    True
# 2            2013-01-28    True
# 3            2013-01-10    True
# 4            2013-01-28    True
# 5            2013-01-13    True
# 6            2013-04-22    True
# 7            2013-04-22    True
# 8            2013-01-13    True
# 9            2013-04-22    True
# 10           2013-04-22    True
# 11           2013-04-22    True
# 12           2013-04-22    True
# 13           2013-01-30    True
# 14           2013-01-30    True
# 15           2013-01-30    True
# 16           2013-01-07    True
# 17           2013-02-08    True
# 18           2013-06-11    True
# 19           2013-12-24    True
# 20           2013-01-07    True
# 21           2013-02-08    True
# 22           2013-06-11    True
# 23           2013-12-24    True
# 24           2013-10-29    True
# 25           2013-07-23    True
# 26           2013-08-15    True
# 27           2013-02-08    True
# 28           2013-03-11    True
# 29           2013-04-09    True
# ...                 ...     ...
# 157961       2013-04-15    True
# 157962       2011-02-28   False
# 157963       2013-04-15   False
# 157964       2011-12-09   False
# 157965       2013-04-15   False
# 157966       2013-04-15   False
# 157967       2013-04-15   False
# 157968       2013-04-15   False
# 157969       2011-07-21   False
# 157970       2013-04-15   False
# 157971       2012-04-16   False
# 157972       2013-04-15   False
# 157973       2009-01-20   False
# 157974       2013-04-15   False
# 157975       2008-04-11   False
# 157976       2013-04-15   False
# 157977       2010-06-02   False
# 157978       2013-04-15   False
# 157979       2011-11-16    True
# 157980       2013-04-15    True
# 157981       2009-01-21   False
# 157982       2009-03-25   False
# 157983       2013-04-15   False
# 157984       2011-07-18   False
# 157985       2013-04-15   False
# 157986       2009-10-20    True
# 157987       2012-05-04    True
# 157988       2013-04-15    True
# 157989       2009-10-21   False
# 157990       2013-04-15   False
#
# [157991 rows x 5 columns]
