# %%
import pandas as pd
import clean
import datetime
import numpy as np
from util import is_between_dates, get_days_stayed_for_quarters_in_year
# For pretty plotting
pd.options.display.mpl_style = 'default'
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
hmis, cp = clean.get_hmis_cp()

# %% [markdown]
# I think these are the important columns:
#
# - `Subject Unique Identifier` is the personal ID;
# - `Family Identifier` is the family ID we generated using an aggressive connected-componenets method, (this is the one that may change as we hear back from Candace, et al.);
# - The dates should be self explanatory;
# - `Family?` is a boolean variable that's set to `True` iff the family ever checked in as a family with at least one child and at least one adult, per the City's definition of a family.

# %%
columns = ['Subject Unique Identifier','Family Identifier','Program Start Date','Program End Date','Family?']

# %%
program=hmis

# %%
program[columns].head()
# Out:
#    Subject Unique Identifier  Family Identifier Program Start Date  \
# 0                      25073              20629         2013-11-15
# 1                       1451                472         2013-01-07
# 2                       1451                472         2013-01-24
# 3                      11524                472         2013-01-07
# 4                      11524                472         2013-01-24
#
#   Program End Date Family?
# 0       2014-04-24   False
# 1       2013-01-10    True
# 2       2013-01-28    True
# 3       2013-01-10    True
# 4       2013-01-28    True

# %%
program['Program Start Year'] = program['Program Start Date'].apply(lambda t: t if pd.isnull(t) else t.year)
program['Program End Year'] = program['Program End Date'].apply(lambda t: t if pd.isnull(t) else t.year)
program['Stay Duration'] = program['Program End Date'] - program['Program Start Date']
program['Days Stayed'] = program['Stay Duration'].apply(lambda t: t.astype('timedelta64[D]')/np.timedelta64(1, 'D'))

# %%
year_range = range(2009, 2014)

# %%
valid_programs = ["Hamilton Family Emergency Shelter", 
                  "Hamilton Family Residence", 
                  "Compass Family Center", 
                  "St. Josephs Family Center"]

# %% [markdown]
# ## Metric 1: How many families are there currently in shelter?

# %%
# Someone is still in a shelther if they entered a program, but 
# does not have a recorded exit date
all_individuals_still_in_shelter = program[program['Program Start Date'].notnull() 
                                           & program['Program End Date'].isnull()]

# %%
all_individuals_still_in_shelter[columns].head()
# Out:
#     Subject Unique Identifier  Family Identifier Program Start Date  \
# 44                       1241               2303         2013-11-14
# 47                         33                823         2013-06-03
# 48                       7273               5428         2013-06-03
# 57                      36907              28806         2014-02-18
# 59                      36907              28806         2014-02-18
#
#    Program End Date Family?
# 44              NaT   False
# 47              NaT   False
# 48              NaT   False
# 57              NaT   False
# 59              NaT   False

# %%
all_individuals_in_families = all_individuals_still_in_shelter[all_individuals_still_in_shelter['Family?']]

# %%
all_individuals_in_families.head()
# Out:
#      Subject Unique Identifier  Participant Site Identifier  \
# 115                      47719                        65709
# 121                      48619                        65708
# 149                      34963                        65746
# 176                      51401                        65764
# 177                      48004                        65763
#
#                           Program Name  Program Unique Identifier  \
# 115                  First Avenues SSO                       1013
# 121                  First Avenues SSO                       1013
# 149          Hamilton Family Residence                        864
# 176  Hamilton Family Emergency Shelter                        863
# 177  Hamilton Family Emergency Shelter                        863
#
#     Program Start Date Program End Date  Family Site Identifier        DOB  \
# 115         2013-11-09              NaT                   27673 1977-11-16
# 121         2013-11-09              NaT                   27673 1990-06-24
# 149         2013-11-26              NaT                   27689 2009-12-18
# 176         2013-08-02              NaT                   27693 2003-01-06
# 177         2013-08-02              NaT                   27693 2006-01-07
#
#     Gender (HUD)      Ethnicity (HUD)   ...            Raw DOB Age Entered  \
# 115         Male  Non-Hispanic/Latino   ...    11/16/1977 0:00          35
# 121       Female  Non-Hispanic/Latino   ...     6/24/1990 0:00          23
# 149         Male  Non-Hispanic/Latino   ...    12/18/2009 0:00           3
# 176         Male      Hispanic/Latino   ...      1/6/2003 0:00          10
# 177         Male      Hispanic/Latino   ...      1/7/2006 0:00           7
#
#     Child?  Adult? Raw Subject Unique Identifier Family Identifier  \
# 115  False    True                         55139              1702
# 121  False    True                         55138              1702
# 149   True   False                         55176               164
# 176   True   False                         55194              1601
# 177   True   False                         55193              1601
#
#     With Child?  With Adult? With Family? Family?
# 115       False         True        False    True
# 121       False         True        False    True
# 149        True         True         True    True
# 176        True         True         True    True
# 177        True         True         True    True
#
# [5 rows x 26 columns]

# %%
all_families = all_individuals_in_families['Family Identifier'].unique()

# %%
# How many families are there in shelters?
len(all_families)
# Out:
# 1195

# %% [markdown]
# 1181 total families seems incredibly large.
#
# But Candace in the intial email that Emily sent with the 6 questions, mentioned we should be counting families in one of the following programs:
#  “Hamilton Family Emergency Shelter”, “Hamilton Family Residence”, “Compass Family Center” and “St. Josephs Family Center”
#
#  Should we include families that are not part of these programs? I think so, but let's just do a sanity check to see how many families are just in these programs.

# %%
individuals_in_programs = all_individuals_in_families[all_individuals_in_families['Program Name'].isin(valid_programs)]

# %%
# Wow, this is a huge deviation from 1181! What the heck is going on?
len(individuals_in_programs['Family Identifier'].unique())
# Out:
# 37

# %%
# This seems to make a bit more sense, though I'm suspicious that are there
# families that have been in these shelters since Oct 2012.
# Is that possible?
individuals_in_programs.sort('Program Start Date')[columns]
# Out:
#         Subject Unique Identifier  Family Identifier Program Start Date  \
# 113583                      54992               3605         2012-10-08
# 154989                      54993               3605         2012-10-08
# 16500                       29793                733         2012-10-19
# 16502                       29794                733         2012-10-19
# 16020                       24276              17645         2012-10-22
# 16011                       24276              17645         2012-10-22
# 51787                       54994               1777         2012-10-29
# 51788                       54996               1777         2012-10-29
# 51789                       54995               1777         2012-10-29
# 51545                       47485                374         2012-12-14
# 51549                       47489                374         2012-12-14
# 51554                       47488                374         2012-12-14
# 51556                       47484                374         2012-12-14
# 51622                        2787                124         2013-01-30
# 51624                       47876                124         2013-01-30
# 51623                       47877                124         2013-01-30
# 51732                       54952               1773         2013-02-25
# 51728                       54585               1773         2013-02-25
# 51803                       23155                685         2013-03-12
# 51804                       47683                685         2013-03-12
# 51805                       23157                685         2013-03-12
# 51806                       23156                685         2013-03-12
# 48299                       48899               3578         2013-04-16
# 51681                        2795                125         2013-04-16
# 51679                        2794                125         2013-04-16
# 51683                        2796                125         2013-04-16
# 48296                       48829               3578         2013-04-16
# 143663                      47621               2142         2013-04-21
# 154992                       7730               2142         2013-04-21
# 16517                       29797               1498         2013-04-24
# ...                           ...                ...                ...
# 46754                       24166               1212         2013-08-31
# 46757                       10682               1212         2013-08-31
# 345                         55303                781         2013-09-03
# 344                         55302                781         2013-09-03
# 343                         41010                781         2013-09-03
# 342                         55303                781         2013-09-03
# 341                         55301                781         2013-09-03
# 143690                      48004               1601         2013-09-07
# 127322                      51401               1601         2013-09-07
# 143688                      39772               1601         2013-09-07
# 12542                       42488                153         2013-09-13
# 12548                       55355                153         2013-09-13
# 588                         21454               2583         2013-10-08
# 590                         55702               2583         2013-10-08
# 599                         55708               1784         2013-10-29
# 598                         55709               1784         2013-10-29
# 597                         55710               1784         2013-10-29
# 149                         34963                164         2013-11-26
# 250                         55227                856         2013-12-06
# 244                         55225                856         2013-12-06
# 246                         55226                856         2013-12-06
# 248                         55224                856         2013-12-06
# 16979                       22408               1348         2014-01-10
# 16984                       22409               1348         2014-01-10
# 16992                       18161               1348         2014-01-10
# 51929                       57703               3646         2014-06-10
# 51928                       57702               3646         2014-06-10
# 52075                       57867               1796         2014-06-23
# 52077                       57869               1796         2014-06-23
# 52076                       57868               1796         2014-06-23
#
#        Program End Date Family?
# 113583              NaT    True
# 154989              NaT    True
# 16500               NaT    True
# 16502               NaT    True
# 16020               NaT    True
# 16011               NaT    True
# 51787               NaT    True
# 51788               NaT    True
# 51789               NaT    True
# 51545               NaT    True
# 51549               NaT    True
# 51554               NaT    True
# 51556               NaT    True
# 51622               NaT    True
# 51624               NaT    True
# 51623               NaT    True
# 51732               NaT    True
# 51728               NaT    True
# 51803               NaT    True
# 51804               NaT    True
# 51805               NaT    True
# 51806               NaT    True
# 48299               NaT    True
# 51681               NaT    True
# 51679               NaT    True
# 51683               NaT    True
# 48296               NaT    True
# 143663              NaT    True
# 154992              NaT    True
# 16517               NaT    True
# ...                 ...     ...
# 46754               NaT    True
# 46757               NaT    True
# 345                 NaT    True
# 344                 NaT    True
# 343                 NaT    True
# 342                 NaT    True
# 341                 NaT    True
# 143690              NaT    True
# 127322              NaT    True
# 143688              NaT    True
# 12542               NaT    True
# 12548               NaT    True
# 588                 NaT    True
# 590                 NaT    True
# 599                 NaT    True
# 598                 NaT    True
# 597                 NaT    True
# 149                 NaT    True
# 250                 NaT    True
# 244                 NaT    True
# 246                 NaT    True
# 248                 NaT    True
# 16979               NaT    True
# 16984               NaT    True
# 16992               NaT    True
# 51929               NaT    True
# 51928               NaT    True
# 52075               NaT    True
# 52077               NaT    True
# 52076               NaT    True
#
# [111 rows x 5 columns]

# %%
# Checking some of these families
# There seem to be many 

# Family identifier 713 seems to have been in the shelters for quite a while.
# I'm assuming this is an error.
all_individuals_in_families[all_individuals_in_families['Family Identifier'] == all_families[99]][columns]
# Out:
#         Subject Unique Identifier  Family Identifier Program Start Date  \
# 6999                         9781               2216         2010-12-29
# 7000                         9780               2216         2010-12-29
# 143584                       9780               2216         2008-08-21
#
#        Program End Date Family?
# 6999                NaT    True
# 7000                NaT    True
# 143584              NaT    True

# %%
all_individuals_in_families.sort('Program Start Date')[columns]
# Out:
#         Subject Unique Identifier  Family Identifier Program Start Date  \
# 155451                         16                172         1995-10-05
# 8670                        12690               2396         1997-02-10
# 8164                        33874                463         1997-03-19
# 8165                         1976                463         1997-03-19
# 8669                        12691               2396         1997-05-01
# 8212                         2167               2010         1997-06-13
# 8210                         2164               2010         1997-06-13
# 8341                         2615               2043         1997-06-20
# 8340                         2613               2043         1997-06-20
# 8085                         1754                452         1998-01-05
# 8086                         1755                452         1998-01-05
# 8087                         1757                452         1998-01-05
# 8088                         1753                452         1998-01-05
# 8457                         3016               1098         1998-04-08
# 8456                         3013               1098         1998-04-08
# 128940                       7885               2146         1998-07-17
# 145612                      10475               2146         1998-07-17
# 15617                       19321                150         1999-04-16
# 15618                       19323                150         1999-04-16
# 15619                       19324                150         1999-04-16
# 15620                       19326                150         1999-04-16
# 15621                       19325                150         1999-04-16
# 15623                       19322                150         1999-04-16
# 11921                       19292               2570         1999-06-01
# 11922                       19293               2570         1999-06-01
# 15645                       29127               2763         1999-07-13
# 15644                       29126               2763         1999-07-13
# 12015                        1536               1959         1999-12-22
# 12058                       46703               2054         1999-12-22
# 12059                       46703               2054         1999-12-22
# ...                           ...                ...                ...
# 52153                       40613                736         2014-07-21
# 107815                      58190               1799         2014-07-21
# 127420                      58191               1799         2014-07-21
# 65339                        1778               1005         2014-07-23
# 64886                        2446               1054         2014-07-23
# 52903                       58303               1801         2014-07-25
# 143954                      58369               3662         2014-07-28
# 143953                      58368               3662         2014-07-28
# 52925                       58324                854         2014-07-28
# 52924                       58325                854         2014-07-28
# 52923                       58323                854         2014-07-28
# 143960                      10918               2301         2014-08-11
# 143969                      36008                130         2014-08-12
# 143961                      11229               1244         2014-08-14
# 114803                      11228               1244         2014-08-14
# 143962                      11227               1244         2014-08-14
# 52253                       58530                 91         2014-08-15
# 20362                        1835               1007         2014-08-21
# 20358                        1835               1007         2014-08-21
# 20350                        1835               1007         2014-08-21
# 20341                        1835               1007         2014-08-21
# 20365                        1835               1007         2014-08-21
# 114858                      54836               3601         2014-08-28
# 127545                      58718               3601         2014-08-28
# 143957                      58488               3666         2014-09-03
# 105338                       1925               1991         2014-09-05
# 53003                       57154               3635         2014-10-03
# 53000                       57155               3635         2014-10-03
# 52998                       57155               3635         2014-10-03
# 53005                       57154               3635         2014-10-03
#
#        Program End Date Family?
# 155451              NaT    True
# 8670                NaT    True
# 8164                NaT    True
# 8165                NaT    True
# 8669                NaT    True
# 8212                NaT    True
# 8210                NaT    True
# 8341                NaT    True
# 8340                NaT    True
# 8085                NaT    True
# 8086                NaT    True
# 8087                NaT    True
# 8088                NaT    True
# 8457                NaT    True
# 8456                NaT    True
# 128940              NaT    True
# 145612              NaT    True
# 15617               NaT    True
# 15618               NaT    True
# 15619               NaT    True
# 15620               NaT    True
# 15621               NaT    True
# 15623               NaT    True
# 11921               NaT    True
# 11922               NaT    True
# 15645               NaT    True
# 15644               NaT    True
# 12015               NaT    True
# 12058               NaT    True
# 12059               NaT    True
# ...                 ...     ...
# 52153               NaT    True
# 107815              NaT    True
# 127420              NaT    True
# 65339               NaT    True
# 64886               NaT    True
# 52903               NaT    True
# 143954              NaT    True
# 143953              NaT    True
# 52925               NaT    True
# 52924               NaT    True
# 52923               NaT    True
# 143960              NaT    True
# 143969              NaT    True
# 143961              NaT    True
# 114803              NaT    True
# 143962              NaT    True
# 52253               NaT    True
# 20362               NaT    True
# 20358               NaT    True
# 20350               NaT    True
# 20341               NaT    True
# 20365               NaT    True
# 114858              NaT    True
# 127545              NaT    True
# 143957              NaT    True
# 105338              NaT    True
# 53003               NaT    True
# 53000               NaT    True
# 52998               NaT    True
# 53005               NaT    True
#
# [4835 rows x 5 columns]

# %%
all_individuals_in_families[all_individuals_in_families['Program Start Date'].apply(lambda t: t.year < 2013)]['Family Identifier'].unique().shape
# Out:
# (795,)

# %% [markdown]
# According to an email from Jennifer, the following information applies to housing limits at each of the four shelters:
#
# 1.       Hamilton Family Emergency Shelter—14 ER beds, no stated limit; 26 – 60 days beds.
#
# 2.       Hamilton Family Residence, 90 day limit
#
# 3.       Compass Family Center, up to 90 days
#
# 4.       St Joseph ( part of Catholic charities, I think) – no stated minimum.  It looks like they try transition homeless families, and pregnant women into permanent housing.
#
#
# See: http://sfhomeless.wikia.com/wiki/Category:Housing_-_Shelters_/_Transitional_Housing

# %%
data_pulled_date = datetime.datetime(2014, 9, 30)

# %%
print data_pulled_date
# Out:
# 2014-09-30 00:00:00

# %%
sorted = individuals_in_programs.sort('Program Start Date')

# %%
sorted.shape
# Out:
# (111, 26)

# %%
sorted.head()
# Out:
#         Subject Unique Identifier  Participant Site Identifier  \
# 113583                      54992                        65562
# 154989                      54993                        65563
# 16500                       29793                        40589
# 16502                       29794                        40590
# 16020                       24276                        40138
#
#                              Program Name  Program Unique Identifier  \
# 113583  Hamilton Family Emergency Shelter                        863
# 154989  Hamilton Family Emergency Shelter                        863
# 16500   Hamilton Family Emergency Shelter                        863
# 16502   Hamilton Family Emergency Shelter                        863
# 16020   Hamilton Family Emergency Shelter                        863
#
#        Program Start Date Program End Date  Family Site Identifier        DOB  \
# 113583         2012-10-08              NaT                   27619 1982-10-16
# 154989         2012-10-08              NaT                   27619 2007-04-06
# 16500          2012-10-19              NaT                    8350 2004-06-20
# 16502          2012-10-19              NaT                    8350 1989-01-25
# 16020          2012-10-22              NaT                    8138 1971-09-07
#
#        Gender (HUD)      Ethnicity (HUD)   ...            Raw DOB Age Entered  \
# 113583         Male  Non-Hispanic/Latino   ...    10/16/1982 0:00          29
# 154989         Male  Non-Hispanic/Latino   ...      4/6/2007 0:00           5
# 16500          Male      Hispanic/Latino   ...     6/20/2004 0:00           8
# 16502        Female      Hispanic/Latino   ...     1/25/1989 0:00          23
# 16020          Male  Non-Hispanic/Latino   ...      9/7/1971 0:00          41
#
#        Child?  Adult? Raw Subject Unique Identifier Family Identifier  \
# 113583  False    True                         54992              3605
# 154989   True   False                         54993              3605
# 16500    True   False                         29793               733
# 16502   False    True                         29794               733
# 16020   False    True                         29342             17645
#
#        With Child?  With Adult? With Family? Family?
# 113583        True         True         True    True
# 154989        True         True         True    True
# 16500         True         True         True    True
# 16502         True         True         True    True
# 16020         True         True         True    True
#
# [5 rows x 26 columns]

# %%
point_in_time = datetime.datetime(2014, 6, 1)

# %%
sorted[columns + ['Program Name']]
# Out:
#         Subject Unique Identifier  Family Identifier Program Start Date  \
# 113583                      54992               3605         2012-10-08
# 154989                      54993               3605         2012-10-08
# 16500                       29793                733         2012-10-19
# 16502                       29794                733         2012-10-19
# 16020                       24276              17645         2012-10-22
# 16011                       24276              17645         2012-10-22
# 51787                       54994               1777         2012-10-29
# 51788                       54996               1777         2012-10-29
# 51789                       54995               1777         2012-10-29
# 51545                       47485                374         2012-12-14
# 51549                       47489                374         2012-12-14
# 51554                       47488                374         2012-12-14
# 51556                       47484                374         2012-12-14
# 51622                        2787                124         2013-01-30
# 51624                       47876                124         2013-01-30
# 51623                       47877                124         2013-01-30
# 51732                       54952               1773         2013-02-25
# 51728                       54585               1773         2013-02-25
# 51803                       23155                685         2013-03-12
# 51804                       47683                685         2013-03-12
# 51805                       23157                685         2013-03-12
# 51806                       23156                685         2013-03-12
# 48299                       48899               3578         2013-04-16
# 51681                        2795                125         2013-04-16
# 51679                        2794                125         2013-04-16
# 51683                        2796                125         2013-04-16
# 48296                       48829               3578         2013-04-16
# 143663                      47621               2142         2013-04-21
# 154992                       7730               2142         2013-04-21
# 16517                       29797               1498         2013-04-24
# ...                           ...                ...                ...
# 46754                       24166               1212         2013-08-31
# 46757                       10682               1212         2013-08-31
# 345                         55303                781         2013-09-03
# 344                         55302                781         2013-09-03
# 343                         41010                781         2013-09-03
# 342                         55303                781         2013-09-03
# 341                         55301                781         2013-09-03
# 143690                      48004               1601         2013-09-07
# 127322                      51401               1601         2013-09-07
# 143688                      39772               1601         2013-09-07
# 12542                       42488                153         2013-09-13
# 12548                       55355                153         2013-09-13
# 588                         21454               2583         2013-10-08
# 590                         55702               2583         2013-10-08
# 599                         55708               1784         2013-10-29
# 598                         55709               1784         2013-10-29
# 597                         55710               1784         2013-10-29
# 149                         34963                164         2013-11-26
# 250                         55227                856         2013-12-06
# 244                         55225                856         2013-12-06
# 246                         55226                856         2013-12-06
# 248                         55224                856         2013-12-06
# 16979                       22408               1348         2014-01-10
# 16984                       22409               1348         2014-01-10
# 16992                       18161               1348         2014-01-10
# 51929                       57703               3646         2014-06-10
# 51928                       57702               3646         2014-06-10
# 52075                       57867               1796         2014-06-23
# 52077                       57869               1796         2014-06-23
# 52076                       57868               1796         2014-06-23
#
#        Program End Date Family?                       Program Name
# 113583              NaT    True  Hamilton Family Emergency Shelter
# 154989              NaT    True  Hamilton Family Emergency Shelter
# 16500               NaT    True  Hamilton Family Emergency Shelter
# 16502               NaT    True  Hamilton Family Emergency Shelter
# 16020               NaT    True  Hamilton Family Emergency Shelter
# 16011               NaT    True  Hamilton Family Emergency Shelter
# 51787               NaT    True  Hamilton Family Emergency Shelter
# 51788               NaT    True  Hamilton Family Emergency Shelter
# 51789               NaT    True  Hamilton Family Emergency Shelter
# 51545               NaT    True  Hamilton Family Emergency Shelter
# 51549               NaT    True  Hamilton Family Emergency Shelter
# 51554               NaT    True  Hamilton Family Emergency Shelter
# 51556               NaT    True  Hamilton Family Emergency Shelter
# 51622               NaT    True          Hamilton Family Residence
# 51624               NaT    True          Hamilton Family Residence
# 51623               NaT    True          Hamilton Family Residence
# 51732               NaT    True  Hamilton Family Emergency Shelter
# 51728               NaT    True  Hamilton Family Emergency Shelter
# 51803               NaT    True          Hamilton Family Residence
# 51804               NaT    True          Hamilton Family Residence
# 51805               NaT    True          Hamilton Family Residence
# 51806               NaT    True          Hamilton Family Residence
# 48299               NaT    True              Compass Family Center
# 51681               NaT    True  Hamilton Family Emergency Shelter
# 51679               NaT    True  Hamilton Family Emergency Shelter
# 51683               NaT    True  Hamilton Family Emergency Shelter
# 48296               NaT    True              Compass Family Center
# 143663              NaT    True              Compass Family Center
# 154992              NaT    True              Compass Family Center
# 16517               NaT    True          Hamilton Family Residence
# ...                 ...     ...                                ...
# 46754               NaT    True              Compass Family Center
# 46757               NaT    True              Compass Family Center
# 345                 NaT    True          Hamilton Family Residence
# 344                 NaT    True          Hamilton Family Residence
# 343                 NaT    True          Hamilton Family Residence
# 342                 NaT    True          Hamilton Family Residence
# 341                 NaT    True          Hamilton Family Residence
# 143690              NaT    True              Compass Family Center
# 127322              NaT    True              Compass Family Center
# 143688              NaT    True              Compass Family Center
# 12542               NaT    True              Compass Family Center
# 12548               NaT    True              Compass Family Center
# 588                 NaT    True          Hamilton Family Residence
# 590                 NaT    True          Hamilton Family Residence
# 599                 NaT    True          Hamilton Family Residence
# 598                 NaT    True          Hamilton Family Residence
# 597                 NaT    True          Hamilton Family Residence
# 149                 NaT    True          Hamilton Family Residence
# 250                 NaT    True          Hamilton Family Residence
# 244                 NaT    True          Hamilton Family Residence
# 246                 NaT    True          Hamilton Family Residence
# 248                 NaT    True          Hamilton Family Residence
# 16979               NaT    True  Hamilton Family Emergency Shelter
# 16984               NaT    True  Hamilton Family Emergency Shelter
# 16992               NaT    True  Hamilton Family Emergency Shelter
# 51929               NaT    True          St. Josephs Family Center
# 51928               NaT    True          St. Josephs Family Center
# 52075               NaT    True          St. Josephs Family Center
# 52077               NaT    True          St. Josephs Family Center
# 52076               NaT    True          St. Josephs Family Center
#
# [111 rows x 6 columns]

# %%
sorted['Days Since Entered Shelter'] = point_in_time - sorted['Program Start Date']

# %%
sorted['Days Since Entered Shelter'].apply(lambda t: t.astype('timedelta64[D]')/np.timedelta64(1, 'D')).hist()

# %%
program[program['Program Name'].isin(["St. Josephs Family Center"])].sort('Program Start Date').tail(50)[columns + ['Program Name']]
# Out:
#         Subject Unique Identifier  Family Identifier Program Start Date  \
# 133357                      23633                 58         2013-11-19
# 55                          55071                 58         2013-11-19
# 148                         47726                165         2013-11-21
# 140                         31485                668         2013-11-21
# 141                         22516                668         2013-11-21
# 146                         47727                165         2013-11-21
# 147                         35424                165         2013-11-21
# 139                         55170                668         2013-11-21
# 851                         47680               3504         2013-11-26
# 850                         47615               3504         2013-11-26
# 148885                       1094                199         2013-12-02
# 104811                      29963                199         2013-12-02
# 146671                       1092                199         2013-12-02
# 146670                       1095                199         2013-12-02
# 146669                       1093                199         2013-12-02
# 854                         55961              29874         2014-01-14
# 1233                        18290               2559         2014-01-15
# 1234                        18290               2559         2014-01-15
# 1243                        18289               2559         2014-01-15
# 1241                        18289               2559         2014-01-15
# 1239                        18289               2559         2014-01-15
# 1238                        18289               2559         2014-01-15
# 1237                        18290               2559         2014-01-15
# 1236                        18290               2559         2014-01-15
# 869                         55975               3616         2014-01-21
# 870                         55974               3616         2014-01-21
# 868                         55974               3616         2014-01-21
# 855                         48406               3527         2014-01-24
# 853                         47941               3527         2014-01-24
# 137776                      18289               2559         2014-01-28
# 1244                        56953              30047         2014-01-28
# 146665                      29477               1483         2014-01-29
# 146666                      29479               1483         2014-01-29
# 104809                      29479               1483         2014-01-29
# 104808                      29477               1483         2014-01-29
# 146674                      23279                687         2014-03-11
# 146673                      23279                687         2014-03-11
# 52947                       57053              30081         2014-03-31
# 52379                       57273                862         2014-04-25
# 52378                       57274                862         2014-04-25
# 52376                       57272                862         2014-04-25
# 52377                       57271                862         2014-04-25
# 52380                       10296               1206         2014-04-30
# 52381                       47700               1206         2014-04-30
# 52382                       48500               1206         2014-04-30
# 51929                       57703               3646         2014-06-10
# 51928                       57702               3646         2014-06-10
# 52077                       57869               1796         2014-06-23
# 52076                       57868               1796         2014-06-23
# 52075                       57867               1796         2014-06-23
#
#        Program End Date Family?               Program Name
# 133357       2014-09-11    True  St. Josephs Family Center
# 55           2014-09-11    True  St. Josephs Family Center
# 148          2014-01-16    True  St. Josephs Family Center
# 140          2014-05-19    True  St. Josephs Family Center
# 141          2014-05-19    True  St. Josephs Family Center
# 146          2014-01-16    True  St. Josephs Family Center
# 147          2014-01-16    True  St. Josephs Family Center
# 139          2014-01-13    True  St. Josephs Family Center
# 851          2014-01-24    True  St. Josephs Family Center
# 850          2014-01-24    True  St. Josephs Family Center
# 148885       2014-03-25    True  St. Josephs Family Center
# 104811       2014-03-26    True  St. Josephs Family Center
# 146671       2014-03-26    True  St. Josephs Family Center
# 146670       2014-03-26    True  St. Josephs Family Center
# 146669       2014-03-26    True  St. Josephs Family Center
# 854          2014-01-23   False  St. Josephs Family Center
# 1233         2014-04-10    True  St. Josephs Family Center
# 1234         2014-04-10    True  St. Josephs Family Center
# 1243         2014-04-10    True  St. Josephs Family Center
# 1241         2014-04-10    True  St. Josephs Family Center
# 1239         2014-04-10    True  St. Josephs Family Center
# 1238         2014-04-10    True  St. Josephs Family Center
# 1237         2014-04-10    True  St. Josephs Family Center
# 1236         2014-04-10    True  St. Josephs Family Center
# 869          2014-01-21    True  St. Josephs Family Center
# 870          2014-03-25    True  St. Josephs Family Center
# 868          2014-03-25    True  St. Josephs Family Center
# 855          2014-06-17   False  St. Josephs Family Center
# 853          2014-02-01   False  St. Josephs Family Center
# 137776       2014-04-10    True  St. Josephs Family Center
# 1244         2014-04-10   False  St. Josephs Family Center
# 146665       2014-06-03    True  St. Josephs Family Center
# 146666       2014-06-03    True  St. Josephs Family Center
# 104809       2014-06-03    True  St. Josephs Family Center
# 104808       2014-06-03    True  St. Josephs Family Center
# 146674       2014-08-28    True  St. Josephs Family Center
# 146673       2014-08-28    True  St. Josephs Family Center
# 52947        2014-06-26   False  St. Josephs Family Center
# 52379        2014-06-03    True  St. Josephs Family Center
# 52378        2014-06-03    True  St. Josephs Family Center
# 52376        2014-06-03    True  St. Josephs Family Center
# 52377        2014-06-03    True  St. Josephs Family Center
# 52380        2014-08-19    True  St. Josephs Family Center
# 52381        2014-08-28    True  St. Josephs Family Center
# 52382        2014-08-19    True  St. Josephs Family Center
# 51929               NaT    True  St. Josephs Family Center
# 51928               NaT    True  St. Josephs Family Center
# 52077               NaT    True  St. Josephs Family Center
# 52076               NaT    True  St. Josephs Family Center
# 52075               NaT    True  St. Josephs Family Center

# %% [markdown]
# ## Num families in shelters across years

# %%
start = program['Program Start Year'].isin([year])
end = program['Program End Year'].isin([year])

# %%
# Looking only at families that have a recorded end date, as they shouldn't 
# be in any of these shelters for multiple years
individuals_in_year = program.loc[program['Program Start Date'].notnull()
                                    & program['Program End Date'].notnull()
                                    & program['Program Name'].isin(valid_programs)
                                    & program['Family?']
                                    & (start | end)]

# %%
individuals_in_year.head()[columns + ['Days Stayed']]
# Out:
#     Subject Unique Identifier  Family Identifier Program Start Date  \
# 51                      55072                 58         2013-11-19
# 52                      55073                 58         2013-11-19
# 53                       3308                 58         2013-11-19
# 54                      55074                 58         2013-11-19
# 55                      55071                 58         2013-11-19
#
#    Program End Date Family?  Days Stayed
# 51       2014-09-11    True          296
# 52       2014-09-11    True          296
# 53       2014-09-11    True          296
# 54       2014-09-11    True          296
# 55       2014-09-11    True          296

# %%
individuals_in_year['Family Identifier'].unique().shape
# Out:
# (28,)

# %% [markdown]
# ## Days Stayed per family

# %%
def normalize_days_stayed(days):
    if pd.isnull(days):
        return days
    elif days >= 90:
        return 90
    else:
        return days

# %%
program['Normalized Days Stayed'] = program['Days Stayed'].apply(normalize_days_stayed)

# %%
year = 2009

# %%
start = program['Program Start Year'].isin([year])
end = program['Program End Year'].isin([year])

# %%
# Looking only at families that have a recorded end date, as they shouldn't 
# be in any of these shelters for multiple years
individuals_in_year = program.loc[program['Program Start Date'].notnull()
                                    & program['Program End Date'].notnull()
                                    & program['Program Name'].isin(valid_programs)
                                    & program['Family?']
                                    & (start | end) ]

# %%
individuals_in_year.sort('Program Start Date')[columns]
# Out:
#         Subject Unique Identifier  Family Identifier Program Start Date  \
# 4667                         1264                974         2008-04-03
# 8621                         9716               1183         2008-07-01
# 8624                         9717               1183         2008-07-01
# 8625                         9718               1183         2008-07-01
# 3170                          736                928         2008-07-25
# 3172                          737                928         2008-07-25
# 3174                          738                928         2008-07-25
# 8674                        12693               1263         2008-07-28
# 8675                        12694               1263         2008-07-28
# 8676                        12692               1263         2008-07-28
# 8320                          876               1895         2008-07-28
# 8317                          875               1895         2008-07-28
# 4123                         1070               1919         2008-10-10
# 8680                        12698               2397         2008-10-14
# 8681                        12699               2397         2008-10-14
# 144605                       9796               1186         2008-10-21
# 3531                          839                423         2008-10-22
# 2635                          638                 97         2008-10-27
# 16637                       13115                 97         2008-10-27
# 2637                          637                 97         2008-10-27
# 3914                        15640               1908         2008-11-11
# 3472                          830               1891         2008-11-14
# 3471                          830               1891         2008-11-14
# 145091                       1358               1891         2008-11-14
# 4801                         1279               1940         2008-12-02
# 3308                          772                420         2008-12-02
# 3316                          772                420         2008-12-02
# 3324                          772                420         2008-12-02
# 3332                          769                420         2008-12-02
# 3348                          769                420         2008-12-02
# ...                           ...                ...                ...
# 146921                       2694               1069         2009-10-30
# 127062                       2693               1069         2009-10-30
# 5797                         8566                533         2009-11-04
# 5790                         8564                533         2009-11-04
# 5796                         8564                533         2009-11-04
# 120586                       8523                527         2009-11-10
# 4089                         1056               1918         2009-11-16
# 4088                         1057               1918         2009-11-16
# 3048                          699               1880         2009-11-16
# 3046                          698               1880         2009-11-16
# 8803                        13640                586         2009-11-17
# 8805                        13638                586         2009-11-17
# 8806                        13641                586         2009-11-17
# 8804                        13639                586         2009-11-17
# 8572                         3419               1124         2009-11-19
# 8574                         3418               1124         2009-11-19
# 8573                         3417               1124         2009-11-19
# 3860                          957                196         2009-11-20
# 5730                         8513                196         2009-11-20
# 3867                          957                196         2009-11-20
# 3864                          957                196         2009-11-20
# 8663                        12685                573         2009-11-25
# 8664                        12686                573         2009-11-25
# 8665                        12684                573         2009-11-25
# 108178                      12669               2395         2009-12-01
# 8073                         1713               1974         2009-12-11
# 8074                         1712               1974         2009-12-11
# 8447                         3003               1095         2009-12-11
# 8448                         3002               1095         2009-12-11
# 8449                         3004               1095         2009-12-11
#
#        Program End Date Family?
# 4667         2009-04-09    True
# 8621         2009-01-02    True
# 8624         2009-01-02    True
# 8625         2009-01-02    True
# 3170         2009-02-03    True
# 3172         2009-02-03    True
# 3174         2009-02-03    True
# 8674         2009-02-06    True
# 8675         2009-02-06    True
# 8676         2009-02-06    True
# 8320         2009-02-04    True
# 8317         2009-02-04    True
# 4123         2009-04-07    True
# 8680         2009-03-24    True
# 8681         2009-03-24    True
# 144605       2009-02-24    True
# 3531         2009-02-23    True
# 2635         2009-06-05    True
# 16637        2009-06-05    True
# 2637         2009-06-05    True
# 3914         2009-06-08    True
# 3472         2009-09-03    True
# 3471         2009-09-03    True
# 145091       2009-09-03    True
# 4801         2009-01-26    True
# 3308         2009-01-25    True
# 3316         2009-01-25    True
# 3324         2009-01-25    True
# 3332         2009-01-25    True
# 3348         2009-01-25    True
# ...                 ...     ...
# 146921       2009-11-06    True
# 127062       2009-11-06    True
# 5797         2010-04-30    True
# 5790         2010-03-01    True
# 5796         2010-03-01    True
# 120586       2010-01-11    True
# 4089         2010-11-01    True
# 4088         2009-12-30    True
# 3048         2009-11-21    True
# 3046         2009-11-21    True
# 8803         2009-11-19    True
# 8805         2009-11-19    True
# 8806         2009-11-19    True
# 8804         2009-11-19    True
# 8572         2010-04-12    True
# 8574         2010-04-12    True
# 8573         2010-04-12    True
# 3860         2010-06-25    True
# 5730         2010-06-25    True
# 3867         2010-06-25    True
# 3864         2010-06-25    True
# 8663         2010-01-20    True
# 8664         2010-01-20    True
# 8665         2010-01-20    True
# 108178       2010-04-15    True
# 8073         2010-06-19    True
# 8074         2010-06-19    True
# 8447         2010-03-23    True
# 8448         2010-03-23    True
# 8449         2010-03-23    True
#
# [350 rows x 5 columns]

# %%
individuals_in_year['Normalized Days Stayed'].hist()

# %%
print individuals_in_year['Family Identifier'].unique().shape[0]
print int(individuals_in_year['Normalized Days Stayed'].sum())
# Out:
# 95
# 21315

# %%
individuals_in_year['Normalized Days Stayed'].sum() / individuals_in_year['Family Identifier'].unique().shape[0]
# Out:
# 224.36842105263159

# %% [markdown]
# ## Looking at the point in time counts

# %%
year = 2014

# %%
point_in_time = datetime.datetime(year, 1, 15)

# %%
pit_counts = program.loc[program['Program Start Date'].notnull()
            & program['Program End Date'].notnull()
            & program['Program Name'].isin(valid_programs)
            & program['Family?']
            & (program['Program Start Date'] <= point_in_time)
            & (program['Program End Date'] >= point_in_time)]

# %%
time_spent = pit_counts['Program End Date'] - pit_counts['Program Start Date']

# %%
# Converting timedelta64 objects to days
time_spent = time_spent.apply(lambda t: t.astype('timedelta64[D]')/np.timedelta64(1, 'D'))

# %%
# These are probably data entry errors
greater_than_6_months = pit_counts[time_spent > 180]

# %%
for i, val in enumerate(greater_than_6_months['Family Identifier'].unique()):
    print int(val)
# Out:
# 58
# 3495
# 1862
# 1653
# 1670

# %% [markdown]
# ## Looking at number of children

# %%
year = 2014

# %%
point_in_time = datetime.datetime(year, 1, 15)

# %%
child_pit_counts = program.loc[program['Program Start Date'].notnull()
            & program['Program End Date'].notnull()
            & program['Program Name'].isin(valid_programs)
            & program['Family?']
            & program['Child?']
            & (program['Program Start Date'] <= point_in_time)
            & (program['Program End Date'] >= point_in_time)]

# %%
child_pit_counts.head(15)[['DOB']]
# Out:
#             DOB
# 52   2000-09-28
# 54   2004-02-23
# 140  2011-08-09
# 146  2011-04-05
# 153  2008-07-11
# 155  2012-04-23
# 162  2010-10-20
# 165  2001-07-28
# 235  2013-03-29
# 302  2009-02-26
# 600  2000-05-15
# 602  2013-05-14
# 603  1999-04-23
# 850  2011-01-06
# 1233 2012-05-25

# %%
child_pit_counts['Subject Unique Identifier'].unique().shape
# Out:
# (29,)

# %% [markdown]
# ## Size of families

# %%
year = 2009

# %%
point_in_time = datetime.datetime(year, 1, 15)

# %%
pit_counts = program.loc[program['Program Start Date'].notnull()
            & program['Program End Date'].notnull()
            & program['Program Name'].isin(valid_programs)
            & program['Family?']
            & (program['Program Start Date'] <= point_in_time)
            & (program['Program End Date'] >= point_in_time)].copy()

# %%
def get_family_size(row, df):
    family_id = row['Family Identifier']
    results = df[df['Family Identifier'] == family_id]
    num_individuals = results['Subject Unique Identifier'].unique().shape[0]
    return num_individuals

# %%
pit_counts['Subject Unique Identifier'].unique().shape[0]
# Out:
# 52

# %%
pit_counts['Family Size'] = pit_counts.apply(get_family_size,
                 df=pit_counts,
                 axis=1)

# %%
pit_counts['Family Size'].hist()

# %%
pit_counts['Family Size'].mean()
# Out:
# 2.736842105263158

# %% [markdown]
# ## Metric 9
# How long did the average family stay in a shelter in each quarter over the past four years? (could we show the distribution of time spent by families - are there some with very long stays)?

# %%
# Testing that this function works as I think it should
begin = datetime.datetime(2012, 1, 1)
end = datetime.datetime(2012, 3, 31)

# %%
mask = program['Program Start Date'].apply(is_between_dates, 
                                begin=begin, 
                                end=end)

# %%
q1_2012 = program[  mask 
                  & program['Family?']
                  & program['Program End Date'].notnull()
                  & program['Program Name'].isin(valid_programs)]

# %%
q1_2012.sort('Program Start Date')[columns].head()
# Out:
#        Subject Unique Identifier  Family Identifier Program Start Date  \
# 17209                       8534                743         2012-01-05
# 18168                        814                800         2012-01-05
# 18169                      33009                800         2012-01-05
# 18170                       2110                800         2012-01-05
# 17202                       8230                743         2012-01-05
#
#       Program End Date Family?
# 17209       2012-03-21    True
# 18168       2012-02-03    True
# 18169       2012-02-03    True
# 18170       2012-02-03    True
# 17202       2012-03-21    True

# %%
# Each family stay is a unique entry
groups = q1_2012.groupby(['Family Identifier', 'Program Start Date'])

# %%
mn = groups['Days Stayed'].mean()
med = groups['Days Stayed'].median()
mx = groups['Days Stayed'].max()

# %%
# It turns out, families stay together and don't have one individual leaving early
# than another. 
# I know this because the mean == median == max for each family stay
# which can only happen if there's uniform distribution for all members
# of a family during a stay
med.values == mx.values
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True], dtype=bool)

# %%
## Actually plotting

# %%
year_range = range(2009, 2014)

# %%
def get_total_days_stayed_for_quarters_in_year(year, program, valid_programs):
    """
    Returns list of 4 values. Each value is the median (or another aggfunc)
    of the days stayed by each family during the quarter.

    e.g., [56, 60, 70, 55] would indicate the median # of days stayed by
    families that entered in Q1 of the year is 56.
    60 for those who entered in Q2 of the year, and so forth.
    """

    #quarter_values = []

    q1 = (datetime.datetime(year, 1, 1), datetime.datetime(year, 3, 31))
    q2 = (datetime.datetime(year, 4, 1), datetime.datetime(year, 6, 30))
    q3 = (datetime.datetime(year, 7, 1), datetime.datetime(year, 9, 30))
    q4 = (datetime.datetime(year, 10, 1), datetime.datetime(year, 12, 31))

    quarters = (q1, q2, q3, q4)
    d = {'q1': None, 'q2': None, 'q3': None, 'q4': None}
    for quarter, k in zip(quarters, d.keys()):
        begin = quarter[0]
        end = quarter[1]
        mask = program['Program Start Date'].apply(is_between_dates,
                                        begin=begin,
                                        end=end)
        q = program[mask
                          & program['Family?']
                          & program['Program End Date'].notnull()
                          & program['Program Name'].isin(valid_programs)]
        groups = q.groupby(['Family Identifier', 'Program Start Date'])
        days_per_stay = groups['Days Stayed'].mean() # taking mean is same as med/max/min
        d[k] = days_per_stay
        #val = aggfunc(days_per_stay)

        #quarter_values.append(val)

    return d #quarter_values

# %%
tdays_09 = get_total_days_stayed_for_quarters_in_year(2009, program, valid_programs=valid_programs)
tdays_10 = get_total_days_stayed_for_quarters_in_year(2010, program, valid_programs=valid_programs)
tdays_11 = get_total_days_stayed_for_quarters_in_year(2011, program, valid_programs=valid_programs)
tdays_12 = get_total_days_stayed_for_quarters_in_year(2012, program, valid_programs=valid_programs)
tdays_13 = get_total_days_stayed_for_quarters_in_year(2013, program, valid_programs=valid_programs)

# %%
one_week = np.array([])
one_month = np.array([])
two_months = np.array([])
three_months = np.array([])
more_than_three_months = np.array([])
for yearly_counts in (tdays_09, tdays_10, tdays_11, tdays_12, tdays_13):
    for quarter in ['q1', 'q2', 'q3', 'q4']:
        period = yearly_counts[quarter]
        week = period[period.values <= 7].shape[0]
        one_week = np.append(one_week, week)
        month = period[period.values <= 30].shape[0]
        one_month= np.append(one_month, month)
        two_month = period[period.values <= 60].shape[0]
        two_months = np.append(two_months, two_month)
        three_month = period[period.values <= 90].shape[0]
        three_months = np.append(three_months, three_month)
        more = period[period.values > 90].shape[0]
        more_than_three_months = np.append(more_than_three_months, more)

# %%
total_counts = one_week + one_month + two_months + three_months + more_than_three_months

# %%
total_counts
# Out:
# array([  38.,   45.,   64.,   39.,   24.,   21.,   19.,   66.,   46.,
#          56.,   44.,  167.,  189.,  134.,  206.,  150.,  166.,   99.,
#         145.,   52.])

# %%
one_week
# Out:
# array([  1.,   2.,   5.,   3.,   0.,   2.,   0.,   6.,   1.,   2.,   2.,
#         13.,  12.,  11.,  18.,  14.,  22.,   9.,  10.,   4.])

# %%
one_week / total_counts
# Out:
# array([ 0.02631579,  0.04444444,  0.078125  ,  0.07692308,  0.        ,
#         0.0952381 ,  0.        ,  0.09090909,  0.02173913,  0.03571429,
#         0.04545455,  0.07784431,  0.06349206,  0.08208955,  0.08737864,
#         0.09333333,  0.13253012,  0.09090909,  0.06896552,  0.07692308])

# %%
r = range(0, 20)

# %%
plt.title('Count of Families Stay Duration', fontsize=12)
plt.plot(one_week/total_counts, label = '1-7 Days')
plt.plot(one_month/total_counts, label = '8-30 Days')
plt.plot(two_months/total_counts, label = '31-60 Days')
plt.plot(three_months/total_counts, label = '61-90 Days')
more = more_than_three_months + one_week + one_month + two_months + three_months
plt.plot(more/total_counts, label='91+ Days')

fill_between(r, 0, one_week/total_counts, color='blue')
fill_between(r, one_week/total_counts, one_month/total_counts, color='purple')
fill_between(r, one_month/total_counts, two_months/total_counts, color='red')
fill_between(r, two_months/total_counts, three_months/total_counts, color='green')
fill_between(r, three_months/total_counts, more/total_counts, color='pink')
plt.legend(loc='best')
tick_labels = []
plt.xlim(xmax=19)
for year in year_range:
    tick_labels.append('Q1 \'{}'.format(str(year)[-2:]))
plt.xticks([0, 4, 8, 12, 16], tick_labels, fontsize=12)
plt.savefig('images/Percent of Families Stay Duration.png', dpi=400)

# %%
plt.title('Count of Families Stay Duration', fontsize=12)
plt.plot(one_week, label = '1-7 Days')
plt.plot(one_month, label = '8-30 Days')
plt.plot(two_months, label = '31-60 Days')
plt.plot(three_months, label = '61-90 Days')
more = more_than_three_months + one_week + one_month + two_months + three_months
plt.plot(more, label='91+ Days')

fill_between(r, 0, one_week, color='blue')
fill_between(r, one_week, one_month, color='purple')
fill_between(r, one_month, two_months, color='red')
fill_between(r, two_months, three_months, color='green')
fill_between(r, three_months, more, color='pink')
plt.legend(loc='best')
tick_labels = []
plt.xlim(xmax=19)
for year in year_range:
    tick_labels.append('Q1 \'{}'.format(str(year)[-2:]))
plt.xticks([0, 4, 8, 12, 16], tick_labels, fontsize=12)
plt.savefig('images/Count of Families Stay Duration.png', dpi=400)

# %%
tick_labels
# Out:
# ["Q1 '09", "Q1 '10", "Q1 '11", "Q1 '12", "Q1 '13"]

# %%
vals = []
for year in year_range:
    q = get_days_stayed_for_quarters_in_year(year, program, valid_programs=valid_programs,
                                         aggfunc=np.median)
    vals += q

# %%
q2009 = get_days_stayed_for_quarters_in_year(2009, program, valid_programs=valid_programs,
                                         aggfunc=np.median)
q2010 = get_days_stayed_for_quarters_in_year(2010, program, valid_programs=valid_programs,
                                         aggfunc=np.median)

# %%
q2009
# Out:
# [44.0, 60.0, 50.0, 137.0]

# %%
q2010
# Out:
# [250.5, 172.5, 65.799999999999997, 43.299999999999997]

# %%
plt.title('Median # Days Spent by Families \n (per quarter per year)', fontsize=12)
plt.plot(range(1, len(vals)+1), vals)

# Labeling the xticks Q1 '9, Q2 '09 and so forth.
tick_labels = []
for year in year_range:
    tick_labels.append('Q1 \'{}'.format(str(year)[-2:]))
plt.xticks(range(1, len(vals)+1,4 ), tick_labels)
plt.savefig('images/Median # Days Spent by Families.png', dpi=400)

# %% [markdown]
# ## Metric 3: On average, how many total families were in a shelter in each of the following years: 2014, 2013, 2012, 2011, 2010
#
# Ike -
# Your proposed solution answers a different question: "How many unique
# families were ever in shelter in a given year?"  I think we need to
# clarify what is meant by "on average" here.  Given that, your proposed
# solution assumes that people don't stay in for more than a year, which
# doesn't generalize to other kinds of programs.  Instead, (e.g. 2013)
# look at the number of families who entered before January 1 2014 and
# exited after January 1 2013.    Also, similar to question 10, I think
# we should consider timeboxing based on when a family *entered*, not if
# they had any overlap at all
#
# Methodology -
#
# (1) Look at 2009 - 2013, and count number of unique families who entered in these given years
#
# (2) Look at 2009 - 2013, and count number of unique who spent any time in any of these years

# %%
# (1) 
# Examining for 2013
individuals_in_families = program[(program['Program Start Year'] == 2013)
                            & program['Family?']
                            & program['Program Name'].isin(valid_programs)]

# %%
# 188 families entered in 2013
individuals_in_families['Family Identifier'].unique().shape
# Out:
# (188,)

# %%
# 607 unique individuals entered in 2013
individuals_in_families['Subject Unique Identifier'].unique().shape
# Out:
# (603,)

# %%
shelter_programs = {name: {'families': [],
                           'individuals': []} for name in valid_programs}

for shelter in shelter_programs:
    num_unique_fams = []
    num_unique_inds = []
    for year in range(2009, 2014):
        individuals_in_families = program[(program['Program Start Year'] == year)
                                & program['Family?']
                                & program['Program Name'].isin([shelter])]
        num_fams = individuals_in_families['Family Identifier'].unique().shape[0]
        num_inds = individuals_in_families['Subject Unique Identifier'].unique().shape[0]
        num_unique_fams.append(num_fams)
        num_unique_inds.append(num_inds)
    shelter_programs[shelter]['families'] = num_unique_fams
    shelter_programs[shelter]['individuals'] = num_unique_inds

# %%
plt.title('# Unique Homeless Families/Individuals \n Entering Shelter')
plt.plot([2009, 2010, 2011, 2012, 2013], num_unique_fams, label='# Unique Families')
plt.plot([2009, 2010, 2011, 2012, 2013], num_unique_inds, label='# Unique Inds')
plt.xticks([2009, 2010, 2011, 2012, 2013], [2009, 2010, 2011, 2012, 2013])
plt.ylabel('Count')
plt.xlabel('Year')
plt.legend(loc='best')

# %%
shelter_programs.keys()
# Out:
# ['St. Josephs Family Center',
#  'Hamilton Family Emergency Shelter',
#  'Compass Family Center',
#  'Hamilton Family Residence']

# %%
plt.title('# Homeless Families Entering Shelter \n Per Shelter', fontsize=12)
for shelter in shelter_programs:
    plt.plot(range(2009, 2014), shelter_programs[shelter]['families'], label=shelter)
plt.xticks(range(2009, 2014), range(2009, 2014))
plt.legend(loc='upper left', fontsize='small')
plt.savefig('# Homeless Families Entering Shelter Per Shelter.png', dpi=400)

# %%
plt.title('# Homeless Individuals Entering Shelter \n Per Shelter', fontsize=12)
for shelter in shelter_programs:
    plt.plot(range(2009, 2014), shelter_programs[shelter]['individuals'], label=shelter)
plt.xticks(range(2009, 2014), range(2009, 2014))
plt.legend(loc='upper left', fontsize='small')
plt.savefig('# Homeless Individuals Entering Shelter Per Shelter.png', dpi=400)

# %% [markdown]
# ## Metric 7: How many families were in shelters on an average night in each quarter over the past four years (use as much data as is available for most recent quarter)?

# %%
def is_between_program_start_end(row, date):
    program_start = row['Program Start Date']
    program_end = row['Program End Date']
    return is_between_dates(date, program_start, program_end)

# %%
START_DATE = '1/1/2009'
END_DATE = '9/20/2013'

# %%
time_series = pd.Series(index=pd.date_range(start=START_DATE, end=END_DATE, freq='D'))

# %%
filtered_program = program[program['Program Name'].isin(valid_programs)
                               & program['Program End Date'].notnull()
                               & program['Family?']]

# %%
for day in time_series.index:
    try: 
        f = filtered_program[filtered_program.apply(is_between_program_start_end, date=day,
                                         axis=1)]
        num_families = f['Family Identifier'].unique().shape[0]
        time_series[day] = num_families
    except Exception as e:
        print day
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-9f061b9ac0cc> in <module>()
#       2     try:
#       3         f = filtered_program[filtered_program.apply(is_between_program_start_end, date=day,
# ----> 4                                          axis=1)]
#       5         num_families = f['Family Identifier'].unique().shape[0]
#       6         time_series[day] = num_families
#
# //anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    3556                     if reduce is None:
#    3557                         reduce = True
# -> 3558                     return self._apply_standard(f, axis, reduce=reduce)
#    3559             else:
#    3560                 return self._apply_broadcast(f, axis)
#
# //anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    3645         else:
#    3646             try:
# -> 3647                 for i, v in enumerate(series_gen):
#    3648                     results[i] = func(v)
#    3649                     keys.append(v.name)
#
# //anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in <genexpr>((i, (arr, name)))
#    3623             values = self.values
#    3624             series_gen = (Series.from_array(arr, index=res_columns, name=name, dtype=dtype)
# -> 3625                           for i, (arr, name) in
#    3626                           enumerate(zip(values, res_index)))
#    3627         else:  # pragma : no cover
#
# //anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in from_array(cls, arr, index, name, dtype, copy, fastpath)
#     221                    fastpath=False):
#     222         # return a sparse series here
# --> 223         if isinstance(arr, ABCSparseArray):
#     224             from pandas.sparse.series import SparseSeries
#     225             cls = SparseSeries
#
# KeyboardInterrupt:

# %%
t = pd.read_csv('count_of_families.csv', header=False)

# %%
time_series = pd.Series(index=pd.date_range(start=START_DATE, end=END_DATE, freq='D'))

# %%
time_series = pd.Series(data=t['count'].values, index=t['date'].values)

# %%
time_series = time_series[:1724] # Truncating at 9/20/2013 as that's the latest date

# %%
time_series.index = pd.to_datetime(time_series.index)

# %%
fig, ax = plt.subplots()
ax.plot_date(time_series.index.to_pydatetime(), time_series.values,
             xdate=True, fmt='b-')
plt.xticks(rotation=-90, fontsize=6)
plt.title('# Families Spending Time \n in Shelters', fontsize=12)
plt.ylabel('Count')
plt.savefig('# Families Spending Time In Shelters.png', dpi=400)

# %% [markdown]
# ### Plotting stacked charts

# %%
# Getting family sizes per entry
filtered_program = program[program['Family?']
                           & program['Program Name'].isin(valid_programs)
                           & program['Program End Date'].notnull()]
grouped = filtered_program.groupby(['Family Identifier', 'Program Start Date'])

# %%
family_sizes = grouped.apply(lambda g: len(unique(g['Subject Unique Identifier'])))

# %%
family_sizes = family_sizes.reset_index().rename(columns={0: 'Family Size'})

# %%
family_sizes.head()
# Out:
#    Family Identifier Program Start Date  Family Size
# 0                  0         2013-01-02            5
# 1                  0         2013-01-25            3
# 2                  0         2013-04-26            4
# 3                  0         2013-05-03            4
# 4                  1         2011-05-16            4

# %%
program = program.merge(family_sizes, left_on=['Family Identifier', 
                                    'Program Start Date'],
                            right_on=['Family Identifier',
                                      'Program Start Date'],
                            how='left')

# %%
program['Family Size'].max()
# Out:
# 12.0

# %%
program['Family Size'].min()
# Out:
# 1.0

# %%
sizes = {fam_size: np.array([]) for fam_size in range(1, 5)}
sizes['5+'] = []
for fam_size in range(1, 5):
    for year in year_range:
        filtered_program = program[(program['Program Start Year'] == year)
            & (program['Family Size'] == fam_size)
            & program['Family?']
            & program['Program Name'].isin(valid_programs)]
        num_families = filtered_program['Family Identifier'].unique().shape[0]
        sizes[fam_size] = np.append(sizes[fam_size], num_families)

for year in year_range:
    filtered_program = program[(program['Program Start Year'] == year)
        & (program['Family Size'] > 4)
        & program['Family?']
        & program['Program Name'].isin(valid_programs)]
    num_families = filtered_program['Family Identifier'].unique().shape[0]
    sizes['5+'] = np.append(sizes['5+'], num_families)

# %%
sizes
# Out:
# {1: array([ 13.,  16.,  28.,  16.,   5.]),
#  2: array([ 32.,  23.,  45.,  89.,  54.]),
#  3: array([ 27.,  25.,  61.,  78.,  63.]),
#  4: array([ 13.,   7.,  14.,  36.,  31.]),
#  '5+': array([  5.,   6.,  11.,  31.,  25.])}

# %%
plt.title('Sizes of Unique Families Entering Shelter \n Over Time', fontsize=12)
plt.plot(year_range, sizes[1], label='1')

y2s = sizes[1] + sizes[2]
plt.plot(year_range, y2s, label='2')

y3s = sizes[1] + sizes[2] + sizes[3]
plt.plot(year_range, y3s, label='3')

y4s = sizes[1] + sizes[2] + sizes[3] + sizes[4]
plt.plot(year_range, y4s, label='4')

y4_plus = sizes[1] + sizes[2] + sizes[3] + sizes[4] + sizes['5+']
plt.plot(year_range, y4_plus, label='5+')

fill_between(year_range, sizes[1], 0, color='blue')
fill_between(year_range, sizes[1], y2s, color='purple')
fill_between(year_range, y2s, y3s, color='red')
fill_between(year_range, y3s, y4s, color='green')
fill_between(year_range, y4s, y4_plus, color='pink')
plt.xticks(year_range, year_range)
plt.ylabel('Count')
plt.legend(loc='best')
plt.savefig('images/Sizes of Families Entering Shelter.png', dpi=400)

# %%
program[(program['Program Start Year'] == 2013)
            & (program['Family Size'] == 1)
            & program['Family?']
            & program['Program Name'].isin(valid_programs)].iloc[0]
# Out:
# Raw Subject Unique Identifier                                  534
# Participant Site Identifier                                  11362
# Program Name                     Hamilton Family Emergency Shelter
# Program Unique Identifier                                      863
# Program Start Date                             2013-12-30 00:00:00
# Program End Date                               2014-01-27 00:00:00
# Family Site Identifier                                         748
# DOB                                            1994-09-13 00:00:00
# Gender (HUD)                                                  Male
# Ethnicity (HUD)                                Non-Hispanic/Latino
# Primary Race (HUD)                       Black or African-American
# Address Line 1                                                 NaN
# City                                                           NaN
# Zipcode                                                        NaN
# Raw Program Start Date                             12/30/2013 0:00
# Raw Program End Date                                1/27/2014 0:00
# Raw DOB                                             9/13/1994 0:00
# Subject Unique Identifier                                    10531
# Family Identifier                                             1726
# Age Entered                                                     19
# Child?                                                       False
# Adult?                                                        True
# With Child?                                                  False
# With Adult?                                                   True
# With Family?                                                 False
# Family?                                                       True
# Family Size                                                      1
# Program Start Year                                            2013
# Program End Year                                              2014
# Stay Duration                                     28 days 00:00:00
# Days Stayed                                                     28
# Name: 2280, dtype: object

# %%
program[program['Family Identifier'] == 1726]
# Out:
#       Raw Subject Unique Identifier  Participant Site Identifier  \
# 2275                            533                        11361
# 2276                            533                        11361
# 2277                            533                        11361
# 2278                            534                        11362
# 2279                            534                        11362
# 2280                            534                        11362
# 2281                            534                        11362
#
#                            Program Name  Program Unique Identifier  \
# 2275          Hamilton Family Residence                        864
# 2276  Hamilton Family Emergency Shelter                        863
# 2277  Hamilton Family Emergency Shelter                        863
# 2278  Hamilton Family Emergency Shelter                        863
# 2279  Hamilton Family Emergency Shelter                        863
# 2280  Hamilton Family Emergency Shelter                        863
# 2281  Hamilton Family Emergency Shelter                        863
#
#      Program Start Date Program End Date  Family Site Identifier        DOB  \
# 2275         2008-05-12       2008-05-13                     748 1968-06-25
# 2276         2006-02-24       2006-03-10                     748 1968-06-25
# 2277         2008-03-27       2008-04-25                     748 1968-06-25
# 2278         2008-03-27       2008-04-25                     748 1994-09-13
# 2279         2008-03-27       2008-04-25                   29996 1994-09-13
# 2280         2013-12-30       2014-01-27                     748 1994-09-13
# 2281         2013-12-30       2014-01-27                   29996 1994-09-13
#
#      Gender (HUD)      Ethnicity (HUD)     ...      Adult? With Child?  \
# 2275         Male  Non-Hispanic/Latino     ...        True       False
# 2276         Male  Non-Hispanic/Latino     ...        True       False
# 2277         Male  Non-Hispanic/Latino     ...        True        True
# 2278         Male  Non-Hispanic/Latino     ...       False        True
# 2279         Male  Non-Hispanic/Latino     ...       False        True
# 2280         Male  Non-Hispanic/Latino     ...        True       False
# 2281         Male  Non-Hispanic/Latino     ...        True       False
#
#      With Adult?  With Family? Family? Family Size Program Start Year  \
# 2275        True         False    True           1               2008
# 2276        True         False    True           1               2006
# 2277        True          True    True           2               2008
# 2278        True          True    True           2               2008
# 2279       False         False    True           2               2008
# 2280        True         False    True           1               2013
# 2281        True         False    True           1               2013
#
#       Program End Year  Stay Duration  Days Stayed
# 2275              2008         1 days            1
# 2276              2006        14 days           14
# 2277              2008        29 days           29
# 2278              2008        29 days           29
# 2279              2008        29 days           29
# 2280              2014        28 days           28
# 2281              2014        28 days           28
#
# [7 rows x 31 columns]

# %% [markdown]
# ## Plotting Average Size of a family over time with total unique families

# %%
n = np.array([])
med_fam = np.array([])
for year in year_range:
    filtered_program = program[(program['Program Start Year'] == year)
        & program['Family?']
        & program['Program Name'].isin(valid_programs)]
    num_families = filtered_program['Family Identifier'].unique().shape[0]
    med_fam_size = filtered_program['Family Size'].mean()
    n = np.append(n, num_families)
    med_fam = np.append(med_fam, med_fam_size)

# %%
arange(3, 4, 0.1)
# Out:
# array([ 3. ,  3.1,  3.2,  3.3,  3.4,  3.5,  3.6,  3.7,  3.8,  3.9])

# %%
fig, ax1 = plt.subplots()
plt.plot(year_range, n, 'b')
ax1.set_ylabel('Count', color='b')
for t1 in ax1.get_yticklabels():
    t1.set_color('b')

ax2 = ax1.twinx()
ax2.plot(year_range, med_fam, 'r')
plt.yticks(np.arange(3, 4, 0.1), np.arange(3, 5, 0.1))
ax2.set_ylabel('Average Family Size', color='r', rotation=)
for t2 in ax2.get_yticklabels():
    t2.set_color('r')
plt.xticks(year_range, year_range)

plt.savefig('images/Count and Family Size over Time.png', dpi=400)
